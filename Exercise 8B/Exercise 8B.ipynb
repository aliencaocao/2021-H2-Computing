# %% [markdown]
# 1. GCE 2014 P1 Q2
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
'''
Q1 - Task 2.1






'''

# %%
# Q1 - Task 2.2

# %%
# Q1 - Task 2.3

# %% [markdown]
# 2. GCE 2016 P1 Q2
# ![image.png](attachment:image.png)

# %%
# Q2 - Task 2.1

# %%
# Q2 - Task 2.2

# %%
# Q2 - Task 2.3

# %% [markdown]
# 3. SP P1 Q2
# ![image.png](attachment:image.png)

# %%
# Q3 - Task 2.1

# %%
# Q3 - Task 2.2
